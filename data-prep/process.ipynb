# %%
import geopandas as gpd
import pandas as pd

# %%
N_STATIONS = 4

# %%
df = pd.read_csv("crawl/out/output.csv")

# %%
# how many channels in each country have boost = true?

df[df['boost'] == True].groupby('country').size()
# Out:
# country
# Afghanistan             1
# American Samoa          2
# Andorra                 7
# Anguilla                2
# Antigua and Barbuda    13
#                        ..
# Vatican City            9
# Vietnam                 8
# Wallis and Futuna       1
# Zimbabwe               18
# Åland Islands           2
# Length: 114, dtype: int64

# %%
df
# Out:
#        place_id channel_id                                       channel_url  \
# 0      zsB2i96x   9NScvYbL            /listen/radio-guaira-fm-103-5/9NScvYbL
# 1      zsB2i96x   hV6HogDQ                /listen/satelital-91-3-fm/hV6HogDQ
# 2      zsB2i96x   ZeV5B8pF          /listen/zp6-radio-guaira-am-840/ZeV5B8pF
# 3      YbzC1bra   zNb88SOa  /listen/bombo-radyo-cauayan-dznc-801-am/zNb88SOa
# 4      YbzC1bra   jgHwc0Ml     /listen/yes-the-best-cauayan-fm-89-7/jgHwc0Ml
# ...         ...        ...                                               ...
# 36889  JbD-sRSy   RPJn4cV4                     /listen/uplift-radio/RPJn4cV4
# 36890  gazm67sP   zoE3PGlT                         /listen/clare-fm/zoE3PGlT
# 36891  ImoDe5KM   KcblV5Jm                         /listen/fm-104-3/KcblV5Jm
# 36892  HOeAn3hV   7EFgAJNh       /listen/clonmellon-community-radio/7EFgAJNh
# 36893  YI4MxKxq   3KMcryox                       /listen/radio-sana/3KMcryox
#
# ...
